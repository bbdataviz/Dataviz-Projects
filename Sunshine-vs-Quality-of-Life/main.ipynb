# %% [markdown]
# Is Sunny Weather correlated with high Quality of Life (QOL)?

# %%
import pandas as pd
import altair as alt

dark = pd.read_csv("https://raw.githubusercontent.com/bbdataviz/dataviz/main/sunshine_darkcities_eng.csv", parse_dates=['Year'])

alt.Chart(dark 
    #title = alt.Title("Does Sunny Weather correlate with high Quality of Life (QOL)?")
).mark_circle(size=150,opacity=1).encode(
    alt.X('City:N', title="Cities"),
    alt.Y('Year:Q', title="Sunhours per year"),
    #column="QOL"
    color=alt.Color('QOL', scale=alt.Scale(scheme='plasma',reverse=False, domain=[3,8]), legend=alt.Legend(title="QOL")), 
    #Color schemes: https://vega.github.io/vega/docs/schemes/
    tooltip=['City', 'Country', alt.Tooltip('Year', title='Sunhours per year'), 'QOL']
).properties(
    width=850,
    height=250
).interactive()
# Out:
# alt.Chart(...)
